# %% [markdown]
# # Write a Program that estimates BMI using weight and height

# %% [markdown]
# Hint:
#     the program accepts Weight inputs in Kg, g and ib (but covert all input to Kg),
#     the program accepts height inputs in Ft, m and inchs (but convert all inputs to Ft)
#
# NOTE: If BMI value ranges between 20 and 30, the output should display "NORMAL" as part of the result
#       If BMI value ranges from 31 and above, the output should display "OVER WEIGHT" as part of the result

# %%
#BMI_formular = weight (kg)/[height(ft)]**2

# %%
weight = float(input("Enter Weight value :"))
unit_weight = input("Enter Unit for weight ==> (kg /g / ibs):").lower()

height = float(input("Enter Height value :"))
unit_height = input("Enter height ==> (ft / m / inch): ").lower()

#conditions for unit_weight, test all kg with ft
if unit_weight =="kg" and unit_height == "ft":
    bmi = round((weight/ height**2) , 3)
    if bmi < 18.5:
        print(f'This {bmi} value indicates UNDER WEIGHT')
        
    elif bmi > 18.5 and bmi < 25.0:
        print(f'This {bmi} value indicates NORMAL')
        
    elif bmi > 30:
        print(f'This {bmi} value indicates OVER WEIGHT')
        
    else:
        print('wrong input')
    

              

#conditions for unit weight,test  g with ft 
if unit_weight == "g" and unit_height == "ft":
    weight_value = weight * 0.001      #convert grams to kg
    bmi = round((weight_value / height**2), 3)
    if bmi < 18.5:
        print(f'This {bmi} value indicates UNDER WEIGHT')
        
    elif bmi > 18.5 and bmi < 25.0:
        print(f'This {bmi} value indicates NORMAL')
        
    elif bmi > 30:
        print(f'This {bmi} value indicates OVER WEIGHT')
    else:
        print('wrong input')
        

              
#conditions for  unit weight test ibs with ft
if unit_weight == "ibs" and unit_height == "ft":
    weight_value =  weight * 0.4536       #convert ibs to kg
    bmi = round((weight_value / height**2), 3)
    if bmi < 18.5:
        print(f'This {bmi} value indicates UNDER WEIGHT')
        
    elif bmi > 18.5 and bmi < 25.0:
        print(f'This {bmi} value indicates NORMAL')
        
    elif bmi > 30:
        print(f'This {bmi} value indicates OVER WEIGHT')
        
    else:
        print('wrong input')


#conditions for unit_weight, test all kg with m
if unit_weight =="kg" and unit_height == "m":
    bmi = round((weight/ height**2)* 1.3 , 3)   #special constant in the case of kg/m**2
    if bmi < 18.5:
        print(f'This {bmi} value indicates UNDER WEIGHT')
        
    elif bmi > 18.5 and bmi < 25.0:
        print(f'This {bmi} value indicates NORMAL')
        
    elif bmi > 30:
        print(f'This {bmi} value indicates OVER WEIGHT')
        
    else:
        print('wrong input!')
           
        

              

#conditions for unit_weight, test all g with m
if unit_weight =="g" and unit_height == "m":
    weight_value = weight * 0.001                    #convert g to kg
    bmi = round((weight_value/ height**2)*1.3 , 3)   #special constant in the case of kg/m**2
    if bmi < 18.5:
        print(f'This {bmi} value indicates UNDER WEIGHT')
        
    elif bmi > 18.5 and bmi < 25.0:
        print(f'This {bmi} value indicates NORMAL')
        
    elif bmi > 30:
        print(f'This {bmi} value indicates OVER WEIGHT')
        
    else:
        print('wrong input')
    
    
#conditions for unit_weight, test all ibs with m
if unit_weight =="g" and unit_height == "m":
    weight_value = weight * 0.45359                   #convert ibs to kg
    bmi = round(((weight_value/ height**2)*1.3) , 3)   #special constant in the case of kg/m**2
    if bmi < 18.5:
        print(f'This {bmi} value indicates UNDER WEIGHT')
        
    elif bmi > 18.5 and bmi < 25.0:
        print(f'This {bmi} value indicates NORMAL')
        
    elif bmi > 30:
        print(f'This {bmi} value indicates OVER WEIGHT')
        
    else:
        print('wrong input')

    
#conditions for unit_weight, test all kg with inch
if unit_weight == "kg" and unit_height == "inch":
    heigh_value = height * 0.08333               #convert inch to ft
    bmi = round((weight_value/ height**2) , 3)   #special constant in the case of kg/m**2
    if bmi < 18.5:
        print(f'This {bmi} value indicates UNDER WEIGHT')
        
    elif bmi > 18.5 and bmi < 25.0:
        print(f'This {bmi} value indicates NORMAL')
        
    elif bmi > 30:
        print(f'This {bmi} value indicates OVER WEIGHT')
        
    else:
        print('wrong input')
        
        
#condition for unit_weight and unit_height, test all g with inch
if unit_weight == "g" and unit_height == "inch":
    weight_value = weight * 0.001               #convert g to kg
    heigh_value = height * 0.08333               #convert inch to ft
    bmi = round((weight_value/height**2), 3) 
    if bmi <18.5:
        print(f'This {bmi} value indicates UNDER WEIGHT')
        
    elif bmi > 18.5 and bmi < 25.0:
        print(f'This {bmi} value indicates  NORMAL')
        
    elif bmi > 30:
        print(f'This {bmi} value indicates OVER WEIGHT')

    else:
        print('wrong input')

        
#condition for unit_weight , test all ibs with inch
if unit_weight == "ibs" and unit_height == "inch":
    bmi = round(((weight/height**2)*703),3)
    if bmi < 18.5:
        print(f'This {bmi} value indicates UNDER WEIGHT')
        
    elif bmi > 18.5 and bmi < 25.0:
        print(f'This {bmi} value indicates NORMAL')
        
    elif bmi > 30:
        print(f'This {bmi} value indicates OVER WEIGHT')
    
    else:
        print('wrong value')
        
else:
    ('wrong input')
# Out:
# Enter Weight value :1
# Enter Unit for weight ==> (kg /g / ibs):kg
# Enter Height value :1
# Enter height ==> (ft / m / inch): m
# This 1.3 value indicates UNDER WEIGHT
